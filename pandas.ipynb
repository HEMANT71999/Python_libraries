# %%
import pandas as pd

# %%
df = pd.read_csv('arihant.csv.txt')

# %%
df
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address',
#        'city'],
#       dtype='object')

# %%
print(df[['id', 'first_name', 'last_name']])
# Out:
#        id first_name      last_name
# 0       1     Joseph      Zaniolini
# 1       2     Freida  Drillingcourt
# 2       3      Nanni         Herity
# 3       4     Orazio       Frayling
# 4       5   Julianne       Murrison
# ..    ...        ...            ...
# 995   996   Parrnell           Jeff
# 996   997        Pat       Warstall
# 997   998     Willyt     Vannuccini
# 998   999     Gaelan     Petrashkov
# 999  1000   Stirling       Francesc
#
# [1000 rows x 3 columns]

# %%
print(df.iloc[0:9])
# Out:
#    id first_name      last_name                           email  gender  \
# 0   1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1   2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2   3      Nanni         Herity        nherity2@statcounter.com  Female
# 3   4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4   5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# 5   6       Lucy          Gamet         lgamet5@list-manage.com  Female
# 6   7      Dyana         Howatt             dhowatt6@amazon.com  Female
# 7   8     Kassey         Herion             kherion7@amazon.com  Female
# 8   9    Chrissy       Hedworth         chedworth8@china.com.cn    Male
#
#        ip_address                   city
# 0  163.168.68.132         Pedro Leopoldo
# 1   97.212.102.79                   Buri
# 2  145.151.178.98                 Claver
# 3  25.199.143.143                 Kungur
# ...

# %%
#print(df.iloc[0:9])
for index, row in df.iterrows():
    print(row['first_name'])
# Out:
# Joseph
# Freida
# Nanni
# Orazio
# Julianne
# Lucy
# Dyana
# Kassey
# Chrissy
# Hyatt
# Felicdad
# Andrew
# Lucais
# Car
# Alvera
# Prescott
# Nariko
# Kalvin
# Isa
# Benedetta
# Poul
# Virgie
# Gillie
# Tabor
# Sarina
# Elbert
# Danita
# Jone
# Merralee
# Charyl
# Giuseppe
# Sutherlan
# Alexander
# Blayne
# Alfredo
# Harman
# Haslett
# Jeanelle
# Hetty
# Elmira
# Granger
# Tobie
# Knox
# Eliot
# Honey
# Karmen
# Fairleigh
# Angelina
# Lilla
# Penn
# Salvidor
# Ker
# Lorne
# Elijah
# Paxton
# Ernie
# Deb
# Morna
# Gregorius
# Raynard
# Harrietta
# Cariotta
# Lisetta
# Danielle
# Ingra
# Ferdinand
# Salomi
# Lurlene
# Penni
# Stormie
# Baily
# Kristofor
# Cherey
# Phillip
# Karil
# Loise
# Rickie
# Orella
# Calli
# Harli
# Edvard
# Almira
# Kort
# Sigmund
# Winna
# Norton
# Moss
# Jeanna
# Kerrin
# Luca
# Faina
# Skelly
# Mike
# Trever
# Ferdinande
# Brenda
# Matthiew
# Rosalie
# Flor
# Ax
# Guglielma
# Kyla
# Brittan
# Corri
# Korney
# Paddie
# Ase
# Susi
# Jo
# Ardelia
# Alis
# Al
# ...

# %%
print(df.iloc[15:17,:])
# Out:
#     id first_name last_name                        email  gender  \
# 15  16   Prescott  Caldeiro  pcaldeirof@chronoengine.com    Male
# 16  17     Nariko    Clunie          nclunieg@utexas.edu  Female
#
#        ip_address      city
# 15  29.81.197.109  Patzicía
# 16   237.85.98.58  Umuarama

# %%
df.loc[df['gender'] == "Male"]
# Out:
#        id first_name   last_name                           email gender  \
# 0       1     Joseph   Zaniolini  jzaniolini0@simplemachines.org   Male
# 3       4     Orazio    Frayling        ofrayling3@economist.com   Male
# 8       9    Chrissy    Hedworth         chedworth8@china.com.cn   Male
# 9      10      Hyatt   Gasquoine           hgasquoine9@google.ru   Male
# 11     12     Andrew        Bath                  abathb@umn.edu   Male
# ..    ...        ...         ...                             ...    ...
# 994   995      Glynn    Wakerley          gwakerleyrm@disqus.com   Male
# 995   996   Parrnell        Jeff             pjeffrn@4shared.com   Male
# 996   997        Pat    Warstall         pwarstallro@dropbox.com   Male
# 998   999     Gaelan  Petrashkov     gpetrashkovrq@hostgator.com   Male
# 999  1000   Stirling    Francesc     sfrancescrr@cyberchimps.com   Male
#
#          ip_address                 city
# 0    163.168.68.132       Pedro Leopoldo
# ...

# %%
df.describe()
# Out:
#                 id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
df.sort_values(['first_name','last_name','gender'],ascending=[1,1,0])
# Out:
#       id first_name    last_name                          email  gender  \
# 938  939     Aarika        Eeles           aeelesq2@example.com  Female
# 944  945      Aaron     Antonsen     aantonsenq8@whitehouse.gov    Male
# 356  357      Aaron        Baker            abaker9w@spiegel.de    Male
# 719  720       Abbe   Trevarthen      atrevarthenjz@tinyurl.com    Male
# 646  647      Abbie       Allett      aalletthy@accuweather.com  Female
# ..   ...        ...          ...                            ...     ...
# 230  231      Yulma   Castagneri    ycastagneri6e@discovery.com    Male
# 814  815       Yuma  Tattershall      ytattershallmm@spiegel.de    Male
# 607  608       Yves       Heynel          yheynelgv@archive.org    Male
# 824  825      Zelig  Sparrowhawk       zsparrowhawkmw@vimeo.com    Male
# 469  470      Zorah    MacMenemy  zmacmenemyd1@seattletimes.com  Female
#
#          ip_address           city
# 938   15.196.17.238  Dawuhanmangli
# ...

# %%
df['number'] = df['id']

# %%
df
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
# ...

# %%
df = df.drop(columns=['number'])

# %%
df
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city  Total
# ...

# %%
df=df.drop(columns=['Total'])

# %%
df
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city
# ...

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)  # axis =1 means horizontal sum if axis =0  sum would be in vertical direction

# %%
df
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city  \
# ...

# %%
cols = list(df.columns.values)

# %%
cols
# Out:
# ['id',
#  'first_name',
#  'last_name',
#  'email',
#  'gender',
#  'ip_address',
#  'city',
#  'Total']

# %%
df.head(5)
# Out:
#    id first_name      last_name                           email  gender  \
# 0   1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1   2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2   3      Nanni         Herity        nherity2@statcounter.com  Female
# 3   4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4   5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
#
#        ip_address                   city  \
# 0  163.168.68.132         Pedro Leopoldo
# 1   97.212.102.79                   Buri
# 2  145.151.178.98                 Claver
# 3  25.199.143.143                 Kungur
# 4  10.186.243.144  Sainte-Luce-sur-Loire
#
#                                        Total
# 0           Male163.168.68.132Pedro Leopoldo
# 1                    Female97.212.102.79Buri
# 2                 Female145.151.178.98Claver
# 3                   Male25.199.143.143Kungur
# 4  Female10.186.243.144Sainte-Luce-sur-Loire

# %%
df = pd.read_csv('new_pokemon_data.csv.txt')

# %%
df
# Out:
#      sr.                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
## Read headers
print(df.columns)

## Read each column
#print(df[['Name', 'Type 1', 'Speed']])

## Read each Row
#print(df.iloc[0:4])
#for index, row in df.iterrows(): #in this .iterrows itreate through rows 
#    print(row['Name'])

## Reaad a specific location (R,C)
#print(df.iloc[15,1])
#df.loc[df['Type 1'] == "Fire"]
# Out:
# Index(['sr.', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df[['Name', 'Type 1', 'Speed']])
# Out:
#                       Name   Type 1  Speed
# 0                Bulbasaur    Grass     45
# 1                  Ivysaur    Grass     60
# 2                 Venusaur    Grass     80
# 3    VenusaurMega Venusaur    Grass     80
# 4               Charmander     Fire     65
# ..                     ...      ...    ...
# 795                Diancie     Rock     50
# 796    DiancieMega Diancie     Rock    110
# 797    HoopaHoopa Confined  Psychic     70
# 798     HoopaHoopa Unbound  Psychic     80
# 799              Volcanion     Fire     70
#
# [800 rows x 3 columns]

# %%
print(df.iloc[0:4])
# Out:
#    sr.                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
for index, row in df.iterrows(): #in this .iterrows itreate through rows 
    print(row['Name'])
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# VenusaurMega Venusaur
# Charmander
# Charmeleon
# Charizard
# CharizardMega Charizard X
# CharizardMega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# BeedrillMega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# PidgeotMega Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran (Female)
# Nidorina
# Nidoqueen
# Nidoran (Male)
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# AlakazamMega Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# ...

# %%
print(df.iloc[15,1])
# Out:
# Butterfree

# %%
df.loc[df['Type 1'] == "Fire"]
# Out:
#      sr.                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.describe()
# Out:
#               sr.          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(['Type 1','Type 2','HP'],ascending=[0,1,1])
# Out:
#      sr.                   Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 347  318               Carvanha  Water   Dark  45      90       20       65
# 374  342              Crawdaunt  Water   Dark  63     120       85       90
# 348  319               Sharpedo  Water   Dark  70     120       40       95
# 349  319  SharpedoMega Sharpedo  Water   Dark  70     140       70      110
# 726  658               Greninja  Water   Dark  72      95       67      103
# ..   ...                    ...    ...    ...  ..     ...      ...      ...
# 136  127                 Pinsir    Bug    NaN  65     125      100       55
# 342  313                Volbeat    Bug    NaN  65      73       55       47
# 343  314               Illumise    Bug    NaN  65      47       55       73
# 447  402             Kricketune    Bug    NaN  77      85       51       55
# 678  617               Accelgor    Bug    NaN  80      70       40      100
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df
# Out:
#      sr.                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df = df.drop(columns=['Total'])

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)  # axis =1 means horizontal sum if axis =0  sum would be in vertical direction

# %%
df
# Out:
#      sr.                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
#cols = list(df.columns.values)
cols = list(df.columns.values)
#df.head(5)cols = list(df.columns.values)
#df.head(5)df.to_csv('modified1.csv',index=False)df.to_csv('modified1.csv',index=False)df.to_csv('modified1.csv',index=False)df.head(5)
# Out:
#    sr.                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4    4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
cols
# Out:
# ['sr.',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
df.to_csv('modified1.csv',index=False)

# %%
df.to_excel('modified_excel.xlsx',index=False)

# %%
df.to_csv('modified_txt1.txt',index=False,sep='\t')

# %%
 new_df=df.loc[(df['Type 1']=='Grass') & (df['Type 2'] == 'Poison') & (df['Attack'] > 65)]
# Out:
#      sr.                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 452  407               Roserade  Grass  Poison   60      70       65      125
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 2        100     80           1      False    525
# 3        120     80           1      False    625
# 50        90     50           1      False    490
# 75        30     40           1      False    300
# ...

# %%
new_df.to_csv('filtered_csv')

# %%
new_df=new_df.reset_index()

# %%
new_df
# Out:
#    index  sr.                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0      2    3               Venusaur  Grass  Poison   80      82       83
# 1      3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 2     50   45              Vileplume  Grass  Poison   75      80       85
# 3     75   69             Bellsprout  Grass  Poison   50      75       35
# 4     76   70             Weepinbell  Grass  Poison   65      90       50
# 5     77   71             Victreebel  Grass  Poison   80     105       65
# 6    452  407               Roserade  Grass  Poison   60      70       65
# 7    652  591              Amoonguss  Grass  Poison  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0      100      100     80           1      False    525
# 1      122      120     80           1      False    625
# 2      110       90     50           1      False    490
# 3       70       30     40           1      False    300
# ...

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#      sr.                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
import re
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I,regex =True)]
#^pi[a-z]* == gives all names starrting with pi if want other names starting with replace pi with other
# Out:
#      sr.                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
df.loc[df['Type 1'] == 'Fire','Legendary'] = True
df
# Out:
#      sr.                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df = pd.read_csv('modified1.csv')

# %%
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test1','Test2']

# %%
df
# Out:
#      sr.                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary  Total
# 0         65       65     45          1     False    318
# ...

# %%
df = pd.read_csv('modified1.csv')
df
# Out:
#      sr.                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)
# Out:
#                  sr.         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
df['count'] = 1
#df.groupby(['Type 1']).sum()
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
for df in pd.read_csv('modified1.csv',chunksize=5):
    print('chunk')
    print(df)
# Out:
# chunk
#    sr.                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4    4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309
# chunk
#    sr.                       Name Type 1  Type 2  HP  Attack  Defense  \
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# ...
